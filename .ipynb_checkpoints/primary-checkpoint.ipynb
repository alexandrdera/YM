# %%
import pandas as pd
import time as t
import xlrd
from pathlib import Path
import shutil
from zipfile import ZipFile
import os

# %%
ts1 = t.time()

# %%
file_1c = t.strftime("%m%d") + "0900.xlsx"
file_path_1c = Path("D:/temp/_primary/", file_1c)
cumulative_file = Path("D:/Analytik/1_Основное планирование/", "01_ИСХОДНИК-НОВ (выгрузка 1С).xlsx")
file_path_out2 = Path("D:/temp/", "01_ИСХОДНИК-НОВ (выгрузка 1С)_ТЕСТ.xlsx")

# %%
df_cf = pd.read_excel(cumulative_file, "TDSheet", usecols="A:O", index_col=False)

# %%
print("Записей в накопетельном файле: ", len(df_cf))
# Out:
# Записей в накопетельном файле:  494918

# %%
df_cf
# Out:
#               Контрагент                               Номенклатура  \
# 0       Авдеева А.Г. ФЛП           Кефир ТМ Живая 1% 1,0 пленка ТУД
# 1       Авдеева А.Г. ФЛП         Кефир ТМ Живая 2,5% 0,5 пленка ТУД
# 2       Авдеева А.Г. ФЛП         Кефир ТМ Живая 2,5% 1,0 пленка ТУД
# 3       Авдеева А.Г. ФЛП  Молоко ТМ Главмолоко 2,5% 0,45 пленка ТУУ
# 4       Авдеева А.Г. ФЛП   Молоко ТМ Главмолоко 2,5% 0,9 пленка ТУУ
# ...                  ...                                        ...
# 494913               NaN                                        NaN
# 494914               NaN                                        NaN
# 494915               NaN                                        NaN
# 494916               NaN                                        NaN
# 494917               NaN                                        NaN
#
#        Товарная группа (св-во Номенклатура)  \
# 0                                     Кефир
# 1                                     Кефир
# 2                                     Кефир
# 3                                    Молоко
# 4                                    Молоко
# ...                                     ...
# 494913                                  NaN
# 494914                                  NaN
# 494915                                  NaN
# 494916                                  NaN
# 494917                                  NaN
#
#        Торговая марка (св-во Номенклатура) Вид упаковки  \
# 0                                    Живая       Пленка
# 1                                    Живая       Пленка
# 2                                    Живая       Пленка
# 3                               Главмолоко       Пленка
# 4                               Главмолоко       Пленка
# ...                                    ...          ...
# 494913                                 NaN          NaN
# 494914                                 NaN          NaN
# 494915                                 NaN          NaN
# 494916                                 NaN          NaN
# 494917                                 NaN          NaN
#
#        Категория клиента (св-во Контрагент)                  Грузополучатель  \
# 0                           Розница_Фоменко           Авдеева А.Г. Шутова ГМ
# 1                           Розница_Фоменко           Авдеева А.Г. Шутова ГМ
# 2                           Розница_Фоменко           Авдеева А.Г. Шутова ГМ
# 3                           Розница_Фоменко  Авдеева А.Г. Коксохимическая ГМ
# 4                           Розница_Фоменко  Авдеева А.Г. Коксохимическая ГМ
# ...                                     ...                              ...
# 494913                                  NaN                              NaN
# 494914                                  NaN                              NaN
# 494915                                  NaN                              NaN
# 494916                                  NaN                              NaN
# 494917                                  NaN                              NaN
#
#           По дням Вид номенклатуры   Основной менеджер покупателя  \
# 0      2021-11-01              КМП        Мусин Роман Адельшаевич
# 1      2021-11-01              КМП        Мусин Роман Адельшаевич
# 2      2021-11-01              КМП        Мусин Роман Адельшаевич
# 3      2021-11-01           Молоко  Косьяненко Роман Вячеславович
# 4      2021-11-01           Молоко  Косьяненко Роман Вячеславович
# ...           ...              ...                            ...
# 494913        NaT              NaN                            NaN
# 494914        NaT              NaN                            NaN
# 494915        NaT              NaN                            NaN
# 494916        NaT              NaN                            NaN
# 494917        NaT              NaN                            NaN
#
#         Количество (в ед. отчетов)  Сумма продажи в (грн)  Количество  \
# 0                             1.00                   25.5         1.0
# 1                             0.50                   15.5         1.0
# 2                             1.00                   28.0         1.0
# 3                             0.45                   11.5         1.0
# 4                             1.80                   42.5         2.0
# ...                            ...                    ...         ...
# 494913                         NaN                    NaN         NaN
# 494914                         NaN                    NaN         NaN
# 494915                         NaN                    NaN         NaN
# 494916                         NaN                    NaN         NaN
# 494917                         NaN                    NaN         NaN
#
#         Сумма продажи без скидок в (грн)  Сумма скидки в (грн)
# 0                                   25.5                   NaN
# 1                                   15.5                   NaN
# 2                                   28.0                   NaN
# 3                                   11.5                   NaN
# 4                                   42.5                   NaN
# ...                                  ...                   ...
# 494913                               NaN                   NaN
# 494914                               NaN                   NaN
# 494915                               NaN                   NaN
# 494916                               NaN                   NaN
# 494917                               NaN                   NaN
#
# [494918 rows x 15 columns]

# %%
df_cf = df_cf.drop(df_cf.loc[df_cf['Категория клиента (св-во Контрагент)'] == "VIP Прямые продажи"].index)
df_cf = df_cf.drop(df_cf.loc[df_cf['Категория клиента (св-во Контрагент)'] == "Дистрибьютор"].index)

# %%
print("Последняя запись в накопителе от ", df_cf["По дням"].max())
# Out:
# Последняя запись в накопителе от  2021-11-23 00:00:00

# %%
file_1c_zip = file_1c.rpartition(".")[0]

# %%
try:
    df_1с = pd.read_excel(file_path_1c, header = 7, usecols="B:P", index_col=False)
except KeyError as ke:
    # Создаем временную папку
    tmp_folder = Path('D:/temp/convert_wrong_excel/')
    os.makedirs(tmp_folder, exist_ok=True)

    # Распаковываем excel как zip в нашу временную папку
    with ZipFile(file_path_1c) as excel_container:
        excel_container.extractall(tmp_folder)

    # Переименовываем файл с неверным названием
    wrong_file_path = os.path.join(tmp_folder, 'xl', 'SharedStrings.xml')
    correct_file_path = os.path.join(tmp_folder, 'xl', 'sharedStrings.xml')

    os.rename(wrong_file_path, correct_file_path)

    # Запаковываем excel обратно в zip, перемещаем и переименовываем в исходный файл
    shutil.make_archive(file_1c_zip, 'zip', tmp_folder)
    shutil.move(os.path.realpath(file_1c_zip + ".zip"), str(file_path_1c))
    
    print("Файл перепакован из-за ошибки: "  + str(ke))

    df_1с = pd.read_excel(file_path_1c, header = 7, usecols="B:P", index_col=False)

# %%
print("Из 1с загружено строк: ", len(df_1с))
# Out:
# Из 1с загружено строк:  147885

# %%
df_1с = df_1с.rename(columns={'Контрагент (категории)':'Категория клиента (св-во Контрагент)',
                     'Пользователь':'Основной менеджер покупателя'})

# %%
df_1с["По дням"] = pd.to_datetime(df_1с["По дням"], format="%d.%m.%Y")

# %%
df_vip1 = df_1с.loc[df_1с['Категория клиента (св-во Контрагент)'] == "VIP Прямые продажи"]
df_vip2 = df_1с.loc[df_1с['Категория клиента (св-во Контрагент)'] == "Дистрибьютор"]

df_vip = pd.concat([df_vip1, df_vip2])

# %%
df_1с = df_1с.drop(df_1с.loc[df_1с['Категория клиента (св-во Контрагент)'] == "VIP Прямые продажи"].index)
df_1c_retail = df_1с.drop(df_1с.loc[df_1с['Категория клиента (св-во Контрагент)'] == "Дистрибьютор"].index)
print("Последняя запись в базе 1с от ", df_1c_retail["По дням"].max())
# Out:
# Последняя запись в базе 1с от  2021-11-30 00:00:00

# %%
df_cf_new = pd.concat([df_cf,
                       df_vip,
                       df_1c_retail.loc[df_1c_retail["По дням"] > df_cf["По дням"].max()]
                      ])

# %%
df_cf_new
# Out:
#                                   Контрагент  \
# 0                           Авдеева А.Г. ФЛП
# 1                           Авдеева А.Г. ФЛП
# 2                           Авдеева А.Г. ФЛП
# 3                           Авдеева А.Г. ФЛП
# 4                           Авдеева А.Г. ФЛП
# ...                                      ...
# 106689           Продукты Украины Инвест ООО
# 106690           Продукты Украины Инвест ООО
# 106691                  Продукты Украины ООО
# 106692                  Продукты Украины ООО
# 114529  Харцызский трубопрокатный завод, ООО
#
#                                      Номенклатура  \
# 0                Кефир ТМ Живая 1% 1,0 пленка ТУД
# 1              Кефир ТМ Живая 2,5% 0,5 пленка ТУД
# 2              Кефир ТМ Живая 2,5% 1,0 пленка ТУД
# 3       Молоко ТМ Главмолоко 2,5% 0,45 пленка ТУУ
# 4        Молоко ТМ Главмолоко 2,5% 0,9 пленка ТУУ
# ...                                           ...
# 106689                           Аренда помещения
# 106690                            Услуги хранения
# 106691                           Аренда помещения
# 106692                     Ответственное хранение
# 114529                           Аренда помещения
#
#        Товарная группа (св-во Номенклатура)  \
# 0                                     Кефир
# 1                                     Кефир
# 2                                     Кефир
# 3                                    Молоко
# 4                                    Молоко
# ...                                     ...
# 106689                                  NaN
# 106690                                  NaN
# 106691                                  NaN
# 106692                                  NaN
# 114529                                  NaN
#
#        Торговая марка (св-во Номенклатура) Вид упаковки  \
# 0                                    Живая       Пленка
# 1                                    Живая       Пленка
# 2                                    Живая       Пленка
# 3                               Главмолоко       Пленка
# 4                               Главмолоко       Пленка
# ...                                    ...          ...
# 106689                                 NaN          NaN
# 106690                                 NaN          NaN
# 106691                                 NaN          NaN
# 106692                                 NaN          NaN
# 114529                                 NaN          NaN
#
#        Категория клиента (св-во Контрагент)  \
# 0                           Розница_Фоменко
# 1                           Розница_Фоменко
# 2                           Розница_Фоменко
# 3                           Розница_Фоменко
# 4                           Розница_Фоменко
# ...                                     ...
# 106689                                  NaN
# 106690                                  NaN
# 106691                                  NaN
# 106692                                  NaN
# 114529                                  NaN
#
#                              Грузополучатель    По дням Вид номенклатуры  \
# 0                     Авдеева А.Г. Шутова ГМ 2021-11-01              КМП
# 1                     Авдеева А.Г. Шутова ГМ 2021-11-01              КМП
# 2                     Авдеева А.Г. Шутова ГМ 2021-11-01              КМП
# 3            Авдеева А.Г. Коксохимическая ГМ 2021-11-01           Молоко
# 4            Авдеева А.Г. Коксохимическая ГМ 2021-11-01           Молоко
# ...                                      ...        ...              ...
# 106689           Продукты Украины Инвест ООО 2021-11-30           Услуга
# 106690           Продукты Украины Инвест ООО 2021-11-30           Услуга
# 106691                  Продукты Украины ООО 2021-11-30           Услуга
# 106692                  Продукты Украины ООО 2021-11-30           Услуга
# 114529  Харцызский трубопрокатный завод, ООО 2021-11-30           Услуга
#
#                              Основной менеджер покупателя  \
# 0                                 Мусин Роман Адельшаевич
# 1                                 Мусин Роман Адельшаевич
# 2                                 Мусин Роман Адельшаевич
# 3                           Косьяненко Роман Вячеславович
# 4                           Косьяненко Роман Вячеславович
# ...                                                   ...
# 106689  Куляко Людмила                                ...
# 106690  Куляко Людмила                                ...
# 106691  Куляко Людмила                                ...
# 106692  Куляко Людмила                                ...
# 114529                                                NaN
#
#         Количество (в ед. отчетов)  Сумма продажи в (грн)  Количество  \
# 0                             1.00                   25.5         1.0
# 1                             0.50                   15.5         1.0
# 2                             1.00                   28.0         1.0
# 3                             0.45                   11.5         1.0
# 4                             1.80                   42.5         2.0
# ...                            ...                    ...         ...
# 106689                        1.00                 1337.5         1.0
# 106690                        1.00                   75.0         1.0
# 106691                        1.00                 3355.0         1.0
# 106692                        1.00                  150.0         1.0
# 114529                        1.00                  608.5         1.0
#
#         Сумма продажи без скидок в (грн)  Сумма скидки в (грн)
# 0                                   25.5                   NaN
# 1                                   15.5                   NaN
# 2                                   28.0                   NaN
# 3                                   11.5                   NaN
# 4                                   42.5                   NaN
# ...                                  ...                   ...
# 106689                            1337.5                   NaN
# 106690                              75.0                   NaN
# 106691                            3355.0                   NaN
# 106692                             150.0                   NaN
# 114529                             608.5                   NaN
#
# [494929 rows x 15 columns]

# %%
df_cf_new = df_cf_new.dropna(subset = ["Количество (в ед. отчетов)"])

# %%
df_cf_new.loc[df_cf_new["Контрагент"] == "Конечный оптовый покупатель", ["Грузополучатель"]] = ""
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_obj = df_cf_new.select_dtypes(['object'])
df_cf_new[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
import xlwings as xw

app_excel = xw.App(visible = True)

wb = xw.Book(cumulative_file)
ws = wb.sheets['TDSheet']
ws.range('A1').options(pd.DataFrame, index=False).value = df_cf_new

wb.api.RefreshAll()
wb.save()


# kill Excel process
'''
wb.close()
app_excel.kill()
del app_excel
'''
# Out:
# '\nwb.close()\napp_excel.kill()\ndel app_excel\n'

# %%
#df_cf_new.to_excel(file_path_out2, sheet_name="TDSheet")

# %%
print("Строк в новом файле: ", len(df_cf_new))
# Out:
# Строк в новом файле:  148061

# %%
print("Время выполнения ", t.time() - ts1)
# Out:
# Время выполнения  1042.4942450523376
